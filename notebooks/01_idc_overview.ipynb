# %% [markdown]
# # IDC Data Landscape
#
# Overview of what imaging data is available in [NCI Imaging Data Commons (IDC)](https://portal.imaging.datacommons.cancer.gov/), focusing on collections most likely to have cross-node data in other CRDC repositories (GDC, PDC).
#
# **Key questions:**
# - How many collections, patients, and series are in IDC?
# - Which collections originate from programs (TCGA, CPTAC, HTAN) that also have data in GDC/PDC?
# - What modalities and cancer types are represented?

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/fedorov/idc-cda/blob/main/notebooks/01_idc_overview.ipynb)

# %%
# %pip install --upgrade -q idc-index

# %%
from idc_index import IDCClient
import pandas as pd
from pathlib import Path

client = IDCClient()
print(f"IDC data version: {client.get_idc_version()}")
# Out:
# IDC data version: v23

# %% [markdown]
# ## Overall IDC Statistics

# %%
stats = client.sql_query("""
    SELECT
        COUNT(DISTINCT collection_id) as collections,
        COUNT(DISTINCT PatientID) as patients,
        COUNT(DISTINCT StudyInstanceUID) as studies,
        COUNT(DISTINCT SeriesInstanceUID) as series,
        SUM(instanceCount) as instances,
        ROUND(SUM(series_size_MB) / 1000, 1) as total_size_GB
    FROM index
""")
stats
# Out:
#    collections  patients  studies  series   instances  total_size_GB
# 0          161     79569   160199  994073  46885909.0        95333.0

# %% [markdown]
# ## Collection-Level Summary

# %%
collections_overview = client.sql_query("""
    SELECT
        collection_id,
        COUNT(DISTINCT PatientID) as num_patients,
        COUNT(DISTINCT StudyInstanceUID) as num_studies,
        COUNT(DISTINCT SeriesInstanceUID) as num_series,
        STRING_AGG(DISTINCT Modality, ', ') as modalities,
        ROUND(SUM(series_size_MB), 1) as total_size_MB
    FROM index
    GROUP BY collection_id
    ORDER BY num_patients DESC
""")

print(f"Total collections: {len(collections_overview)}")
collections_overview.head(20)
# Out:
# Total collections: 161
#                     collection_id  num_patients  num_studies  num_series  \
# 0                            nlst         26410        73574      590572
# 1                       cbis_ddsm          6671         6775        6775
# 2     breast_cancer_screening_dbt          5060         5610       22032
# 3                        ccdi_mci          4407         4447        4576
# 4                          victre          2994         8749        8749
# 5                            cmmd          1775         1775        1775
# 6                 covid_19_ny_sbu          1384         7361       17950
# 7          prostate_mri_us_biopsy          1151         2799       10373
# 8                       tcga_brca          1098         1263       10463
# 9                       lidc_idri          1010         1308       15116
# 10  acrin_contralateral_breast_mr           984         1103       10184
# 11                           gtex           971          971       25503
# 12         duke_breast_cancer_mri           922          922        6058
# 13                ct_colonography           825          836        3451
# 14                          ispy2           719         2688       32411
# 15    advanced_mri_breast_lesions           632          632        6811
# 16                      upenn_gbm           630         3301        6064
# 17                       tcga_gbm           607          607        4286
# 18                        tcga_ov           591          912        2537
# 19                      tcga_ucec           560          786        4893
#
#                         modalities  total_size_MB
# 0                  SM, CT, SEG, SR     26354752.4
# 1                               MG       163513.4
# 2                               MG      1637811.8
# 3                               SM      4657163.3
# 4                               MG      1027187.6
# 5                               MG        22863.3
# 6   CT, DX, MR, OT, CR, PT, SR, NM       511483.8
# 7                 US, MR, SEG, M3D        81643.4
# 8         SEG, MG, SR, ANN, SM, MR      4801057.0
# 9              SEG, SR, CR, DX, CT       136545.5
# 10                          MR, CR       199592.6
# 11                              SM      8554686.4
# 12                         SEG, MR       377372.4
# 13                              CT       496673.4
# 14                         MR, SEG      1746234.5
# 15                         SEG, MR       645615.7
# 16                         SEG, MR       141312.7
# 17                OT, ANN, SM, SEG      1057632.3
# 18             SEG, SM, CT, MR, OT       516249.7
# 19    PT, CR, SEG, MR, SM, CT, ANN      2065212.8

# %% [markdown]
# ## Collections Index — Cancer Types and Tumor Locations

# %%
client.fetch_index("collections_index")

collections_info = client.sql_query("""
    SELECT collection_id, CancerTypes, TumorLocations, Species, Subjects, SupportingData
    FROM collections_index
    ORDER BY Subjects DESC
""")
collections_info.head(20)
# Out:
# 2026-02-16 13:09:22,188 - Index collections_index already installed, loading from /Users/af61/github/idc-cda/.venv/lib/python3.11/site-packages/idc_index_data/collections_index.parquet
#                     collection_id  \
# 0                            nlst
# 1                       cbis_ddsm
# 2     breast_cancer_screening_dbt
# 3                        ccdi_mci
# 4                          victre
# 5                            cmmd
# 6                 covid_19_ny_sbu
# 7          prostate_mri_us_biopsy
# 8                       tcga_brca
# 9                       lidc_idri
# 10  acrin_contralateral_breast_mr
# 11                           gtex
# 12         duke_breast_cancer_mri
# 13                ct_colonography
# 14                          ispy2
# 15    advanced_mri_breast_lesions
# 16                      upenn_gbm
# 17                       tcga_gbm
# 18                        tcga_ov
# 19                      tcga_luad
#
#                                     CancerTypes TumorLocations Species  \
# 0                       Lung Cancer, Non-Cancer          Chest   Human
# 1                     Breast Cancer, Non-Cancer         Breast   Human
# 2                     Breast Cancer, Non-Cancer         Breast   Human
# 3                                       Various        Various   Human
# 4                                 Breast Cancer         Breast   Human
# 5                                 Breast Cancer         Breast   Human
# 6                         COVID-19 (non-cancer)           Lung   Human
# 7                               Prostate Cancer       Prostate   Human
# 8                                 Breast Cancer         Breast   Human
# 9   Lung Cancer, Non-Cancer, Metastatic disease          Chest   Human
# 10                                Breast Cancer         Breast   Human
# 11                                 Non-diseased        Various   Human
# 12                                Breast Cancer         Breast   Human
# 13                                 Colon Cancer          Colon   Human
# 14                                Breast Cancer         Breast   Human
# 15                                Breast Cancer         Breast   Human
# 16                                 Glioblastoma          Brain   Human
# 17                      Glioblastoma Multiforme          Brain   Human
# 18            Ovarian Serous Cystadenocarcinoma          Ovary   Human
# 19                          Lung Adenocarcinoma          Chest   Human
#
#     Subjects                                     SupportingData
# 0      26410                                           Clinical
# 1       6671                                     Image Analyses
# 2       5060                     Clinical, Software/Source Code
# 3       4407                                               None
# 4       2994                               Software/Source Code
# 5       1775                                           Clinical
# 6       1384                           Clinical, Image Analyses
# 7       1151                                     Image Analyses
# 8       1098  Clinical, Genomics, Image Analyses, Histopatho...
# 9       1010     Clinical, Image Analyses, Software/Source Code
# 10       984                                           Clinical
# 11       971                                 Clinical, Genomics
# 12       922                 Clinical, Genomics, Image Analyses
# 13       825                                     Image Analyses
# 14       719                           Clinical, Image Analyses
# 15       632                                           Clinical
# 16       630                           Clinical, Image Analyses
# 17       607  Clinical, Genomics, Image Analyses, Histopatho...
# 18       591  Clinical, Genomics, Image Analyses, Histopatho...
# 19       560  Clinical, Genomics, Histopathology, Image Anal...

# %% [markdown]
# ## Cross-Node Candidate Collections
#
# Collections from TCGA, CPTAC, and HTAN are most likely to have corresponding data in GDC (genomics) and PDC (proteomics).

# %%
# Tag collections by program
def tag_program(collection_id):
    cid = collection_id.lower()
    if cid.startswith('tcga_'):
        return 'TCGA'
    elif cid.startswith('cptac_'):
        return 'CPTAC'
    elif cid.startswith('htan_'):
        return 'HTAN'
    else:
        return 'Other'

collections_overview['program'] = collections_overview['collection_id'].apply(tag_program)

program_summary = collections_overview.groupby('program').agg(
    collections=('collection_id', 'count'),
    total_patients=('num_patients', 'sum'),
    total_series=('num_series', 'sum'),
    total_size_MB=('total_size_MB', 'sum')
).sort_values('total_patients', ascending=False)

program_summary
# Out:
#          collections  total_patients  total_series  total_size_MB
# program
# Other            112           66380        903078     63992362.7
# TCGA              32           11050         76292     26814517.8
# CPTAC             13            2151         14340      2880061.6
# HTAN               4              68           363      1646019.3

# %%
# TCGA collections detail
tcga = collections_overview[collections_overview['program'] == 'TCGA'].copy()
print(f"TCGA: {len(tcga)} collections, {tcga['num_patients'].sum()} total patients")
tcga
# Out:
# TCGA: 32 collections, 11050 total patients
#     collection_id  num_patients  num_studies  num_series  \
# 8       tcga_brca          1098         1263       10463
# 17       tcga_gbm           607          607        4286
# 18        tcga_ov           591          912        2537
# 19      tcga_ucec           560          786        4893
# 20      tcga_luad           560          674        4868
# 21      tcga_kirc           537          976        6038
# 22      tcga_hnsc           523          523        2163
# 23       tcga_lgg           516          516        1572
# 25      tcga_thca           507          514        1186
# 26      tcga_lusc           504          578        4170
# 28      tcga_prad           500          520        3336
# 29      tcga_skcm           470          470        3160
# 30      tcga_coad           464          492        3766
# 31      tcga_stad           443          489        3449
# 33      tcga_blca           412          604        3876
# 36      tcga_lihc           377          614        3457
# 41      tcga_cesc           307          364        2370
# 42      tcga_kirp           291          338        1168
# 43      tcga_sarc           261          267        1431
# 60      tcga_esca           185          202         834
# 61      tcga_paad           185          185        1414
# 62      tcga_pcpg           179          179         385
# 67      tcga_read           171          175        1381
# 69      tcga_tgct           150          150         721
# 73      tcga_thym           124          124         560
# 77      tcga_kich           113          128         450
# 84       tcga_acc            92           92         969
# 90      tcga_meso            87           87         525
# 93       tcga_uvm            80           80         497
# 105      tcga_ucs            57           57         154
# 111     tcga_chol            51           51         110
# 113     tcga_dlbc            48           48         103
#
#                            modalities  total_size_MB program
# 8            SEG, MG, SR, ANN, SM, MR      4801057.0    TCGA
# 17                   OT, ANN, SM, SEG      1057632.3    TCGA
# 18                SEG, SM, CT, MR, OT       516249.7    TCGA
# 19       PT, CR, SEG, MR, SM, CT, ANN      2065212.8    TCGA
# 20           SM, CT, ANN, SEG, PT, NM      1284054.7    TCGA
# 21                SM, CT, MR, SEG, CR       923543.4    TCGA
# 22                            SEG, SM       574052.9    TCGA
# 23                                 SM      1194590.0    TCGA
# 25                         SM, CT, PT       766136.5    TCGA
# 26           PT, NM, SEG, SM, CT, ANN      1101495.1    TCGA
# 28           PT, SEG, MR, SM, CT, ANN      1059659.7    TCGA
# 29                       SM, ANN, SEG      1345955.4    TCGA
# 30               ANN, OT, SM, CT, SEG       931178.7    TCGA
# 31                   SM, CT, ANN, SEG      1135001.1    TCGA
# 33   CT, SM, DX, MR, ANN, PT, CR, SEG      1532251.9    TCGA
# 36                PT, SEG, MR, SM, CT       698201.3    TCGA
# 41                   SM, ANN, MR, SEG       621551.1    TCGA
# 42                PT, SEG, SM, CT, MR       432507.1    TCGA
# 43                    SM, CT, MR, SEG      1151228.4    TCGA
# 60                        SM, CT, SEG       253317.2    TCGA
# 61                       SEG, ANN, SM       555781.2    TCGA
# 62                                 SM       354667.5    TCGA
# 67               MR, ANN, SM, CT, SEG       290764.7    TCGA
# 69                            SM, SEG       472956.5    TCGA
# 73                            SM, SEG       327381.2    TCGA
# 77                    CT, SM, MR, SEG       318861.6    TCGA
# 84                            SM, SEG       431165.0    TCGA
# 90                            SM, SEG       114682.9    TCGA
# 93                       SEG, ANN, SM       179405.6    TCGA
# 105                                SM       168286.7    TCGA
# 111                                SM        99566.5    TCGA
# 113                                SM        56122.1    TCGA

# %%
# CPTAC collections detail
cptac = collections_overview[collections_overview['program'] == 'CPTAC'].copy()
print(f"CPTAC: {len(cptac)} collections, {cptac['num_patients'].sum()} total patients")
cptac
# Out:
# CPTAC: 13 collections, 2151 total patients
#    collection_id  num_patients  num_studies  num_series  \
# 44    cptac_ucec           254          396        3459
# 47    cptac_luad           244          319        1585
# 51   cptac_ccrcc           233          319        2321
# 54    cptac_lscc           212          255        1314
# 57    cptac_brca           198          198         653
# 59     cptac_pda           195          302        2226
# 63     cptac_gbm           178          178         462
# 64    cptac_coad           178          178         372
# 78   cptac_hnscc           112          112         390
# 82      cptac_cm            95          114         597
# 86     cptac_aml            91           98         169
# 88     cptac_sar            88          121         570
# 97      cptac_ov            73           73         222
#
#                       modalities  total_size_MB program
# 44  RTSTRUCT, US, MR, SM, CT, PT       257358.4   CPTAC
# 47                PT, MR, CT, SM       521547.8   CPTAC
# 51     CT, SM, MR, RTSTRUCT, SEG       277023.8   CPTAC
# 54                    PT, SM, CT       509698.9   CPTAC
# 57                            SM       123127.4   CPTAC
# 59  CT, SM, MR, RTSTRUCT, US, PT       170155.5   CPTAC
# 63                            SM       100948.5   CPTAC
# 64                            SM        70234.4   CPTAC
# 78                            SM       111422.2   CPTAC
# 82                MR, SM, CT, PT       156256.7   CPTAC
# 86                    SM, CT, US       425271.7   CPTAC
# 88                SM, CT, MR, PT        98590.6   CPTAC
# 97                            SM        58425.7   CPTAC

# %%
# HTAN collections detail
htan = collections_overview[collections_overview['program'] == 'HTAN'].copy()
print(f"HTAN: {len(htan)} collections, {htan['num_patients'].sum()} total patients")
htan
# Out:
# HTAN: 4 collections, 68 total patients
#        collection_id  num_patients  num_studies  num_series modalities  \
# 124  htan_vanderbilt            30           30          30         SM
# 130       htan_wustl            21           21         228     PR, SM
# 141         htan_hms            16           16          31     SM, PR
# 160        htan_ohsu             1            1          74     SM, PR
#
#      total_size_MB program
# 124        69497.9    HTAN
# 130        12254.8    HTAN
# 141      1232544.7    HTAN
# 160       331721.9    HTAN

# %% [markdown]
# ## Extract PatientIDs for Cross-Node Candidate Collections
#
# Get distinct PatientIDs from TCGA and CPTAC collections for later cross-referencing with CDA.

# %%
# All TCGA patient IDs
tcga_patients = client.sql_query("""
    SELECT DISTINCT collection_id, PatientID
    FROM index
    WHERE collection_id LIKE 'tcga_%'
    ORDER BY collection_id, PatientID
""")
print(f"TCGA patients in IDC: {len(tcga_patients)}")
tcga_patients.head(10)
# Out:
# TCGA patients in IDC: 11050
#   collection_id     PatientID
# 0      tcga_acc  TCGA-OR-A5J1
# 1      tcga_acc  TCGA-OR-A5J2
# 2      tcga_acc  TCGA-OR-A5J3
# 3      tcga_acc  TCGA-OR-A5J4
# 4      tcga_acc  TCGA-OR-A5J5
# 5      tcga_acc  TCGA-OR-A5J6
# 6      tcga_acc  TCGA-OR-A5J7
# 7      tcga_acc  TCGA-OR-A5J8
# 8      tcga_acc  TCGA-OR-A5J9
# 9      tcga_acc  TCGA-OR-A5JA

# %%
# All CPTAC patient IDs
cptac_patients = client.sql_query("""
    SELECT DISTINCT collection_id, PatientID
    FROM index
    WHERE collection_id LIKE 'cptac_%'
    ORDER BY collection_id, PatientID
""")
print(f"CPTAC patients in IDC: {len(cptac_patients)}")
cptac_patients.head(10)
# Out:
# CPTAC patients in IDC: 2151
#   collection_id  PatientID
# 0     cptac_aml  C3L-00452
# 1     cptac_aml  C3L-00453
# 2     cptac_aml  C3L-00455
# 3     cptac_aml  C3L-00457
# 4     cptac_aml  C3L-00458
# 5     cptac_aml  C3L-00459
# 6     cptac_aml  C3L-00460
# 7     cptac_aml  C3L-00461
# 8     cptac_aml  C3L-00465
# 9     cptac_aml  C3L-00540

# %%
# All HTAN patient IDs
htan_patients = client.sql_query("""
    SELECT DISTINCT collection_id, PatientID
    FROM index
    WHERE collection_id LIKE 'htan_%'
    ORDER BY collection_id, PatientID
""")
print(f"HTAN patients in IDC: {len(htan_patients)}")
htan_patients.head(10)
# Out:
# HTAN patients in IDC: 68
#   collection_id PatientID
# 0      htan_hms  HTA7_920
# 1      htan_hms  HTA7_922
# 2      htan_hms  HTA7_925
# 3      htan_hms  HTA7_926
# 4      htan_hms  HTA7_927
# 5      htan_hms  HTA7_931
# 6      htan_hms  HTA7_932
# 7      htan_hms  HTA7_934
# 8      htan_hms  HTA7_940
# 9      htan_hms  HTA7_947

# %% [markdown]
# ## Modality Distribution Across Programs

# %%
modality_by_program = client.sql_query("""
    SELECT
        CASE
            WHEN collection_id LIKE 'tcga_%' THEN 'TCGA'
            WHEN collection_id LIKE 'cptac_%' THEN 'CPTAC'
            WHEN collection_id LIKE 'htan_%' THEN 'HTAN'
            ELSE 'Other'
        END as program,
        Modality,
        COUNT(DISTINCT PatientID) as patients,
        COUNT(DISTINCT SeriesInstanceUID) as series
    FROM index
    GROUP BY program, Modality
    ORDER BY program, patients DESC
""")
modality_by_program
# Out:
#    program  Modality  patients  series
# 0    CPTAC        SM      2107    7377
# 1    CPTAC        CT       346    3143
# 2    CPTAC  RTSTRUCT       235    1789
# 3    CPTAC        MR        81    1907
# 4    CPTAC        PT        29      80
# 5    CPTAC       SEG        14      37
# 6    CPTAC        US         7       7
# 7     HTAN        SM        68     257
# 8     HTAN        PR        25     106
# 9    Other       SEG     34041  160420
# 10   Other        CT     33956  242495
# 11   Other        SR     28926  270523
# 12   Other        MG     17021   48106
# 13   Other        MR      7626  117056
# 14   Other        SM      7162   33423
# 15   Other        CR      1696   12394
# 16   Other  RTSTRUCT      1512    3149
# 17   Other        US      1404    2233
# 18   Other        PT      1049    3805
# 19   Other       M3D       842    2328
# 20   Other        DX       665    3694
# 21   Other    RTDOSE       282     524
# 22   Other       ANN       246    1033
# 23   Other    RTPLAN       242     484
# 24   Other        PR        41    1086
# 25   Other       REG        23      97
# 26   Other        NM        21      84
# 27   Other       RWV        20      20
# 28   Other        XA        15      34
# 29   Other        KO        10      40
# 30   Other    FUSION         6      18
# 31   Other        OT         2       9
# 32   Other        RF         2      12
# 33   Other        SC         2       7
# 34   Other        XC         2       4
# 35    TCGA        SM     11007   30075
# 36    TCGA       SEG      7968   27556
# 37    TCGA       ANN      5185    6075
# 38    TCGA        CT       870    6370
# 39    TCGA        MR       355    5109
# 40    TCGA        OT       338     693
# 41    TCGA        SR       139     164
# 42    TCGA        PT        65     180
# 43    TCGA        CR         9      22
# 44    TCGA        DX         7      18
# 45    TCGA        MG         5      19
# 46    TCGA        NM         4      11

# %% [markdown]
# ## Save Results for Cross-Node Analysis

# %%
data_dir = Path('data')
data_dir.mkdir(exist_ok=True)

collections_overview.to_csv(data_dir / 'collections_overview.csv', index=False)
tcga_patients.to_csv(data_dir / 'tcga_patients.csv', index=False)
cptac_patients.to_csv(data_dir / 'cptac_patients.csv', index=False)
htan_patients.to_csv(data_dir / 'htan_patients.csv', index=False)

print("Saved:")
print(f"  collections_overview.csv: {len(collections_overview)} rows")
print(f"  tcga_patients.csv: {len(tcga_patients)} rows")
print(f"  cptac_patients.csv: {len(cptac_patients)} rows")
print(f"  htan_patients.csv: {len(htan_patients)} rows")
