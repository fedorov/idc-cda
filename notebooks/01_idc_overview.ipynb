# %% [markdown]
# # IDC Data Landscape
#
# Overview of what imaging data is available in [NCI Imaging Data Commons (IDC)](https://portal.imaging.datacommons.cancer.gov/), focusing on collections most likely to have cross-node data in other CRDC repositories (GDC, PDC).
#
# **Key questions:**
# - How many collections, patients, and series are in IDC?
# - Which collections originate from programs (TCGA, CPTAC, HTAN) that also have data in GDC/PDC?
# - What modalities and cancer types are represented?

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/fedorov/idc-cda/blob/main/notebooks/01_idc_overview.ipynb)

# %%
# %pip install --upgrade -q idc-index
# Out:
# /Users/af61/github/idc-cda/.venv/bin/python3: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from idc_index import IDCClient
import pandas as pd
from pathlib import Path

client = IDCClient()
print(f"IDC data version: {client.get_idc_version()}")
# Out:
# IDC data version: v24

# %% [markdown]
# ## Overall IDC Statistics

# %%
stats = client.sql_query("""
    SELECT
        COUNT(DISTINCT collection_id) as collections,
        COUNT(DISTINCT PatientID) as patients,
        COUNT(DISTINCT StudyInstanceUID) as studies,
        COUNT(DISTINCT SeriesInstanceUID) as series,
        SUM(instanceCount) as instances,
        ROUND(SUM(series_size_MB) / 1000, 1) as total_size_GB
    FROM index
""")
stats
# Out:
#    collections  patients  studies   series   instances  total_size_GB
# 0          176     85362   166740  1032911  57409445.0        99266.9

# %% [markdown]
# ## Collection-Level Summary

# %%
collections_overview = client.sql_query("""
    SELECT
        collection_id,
        COUNT(DISTINCT PatientID) as num_patients,
        COUNT(DISTINCT StudyInstanceUID) as num_studies,
        COUNT(DISTINCT SeriesInstanceUID) as num_series,
        STRING_AGG(DISTINCT Modality, ', ') as modalities,
        ROUND(SUM(series_size_MB), 1) as total_size_MB
    FROM index
    GROUP BY collection_id
    ORDER BY num_patients DESC
""")

print(f"Total collections: {len(collections_overview)}")
collections_overview.head(20)
# Out:
# Total collections: 176
#                     collection_id  num_patients  num_studies  num_series  \
# 0                            nlst         26410        73574      590572
# 1                       cbis_ddsm          6671         6775        6775
# 2     breast_cancer_screening_dbt          5060         5610       22032
# 3                        ccdi_mci          4407         4447        4576
# 4                          victre          2994         8749        8749
# 5                          eay131          2813         3124       30293
# 6                            cmmd          1775         1775        1775
# 7                 covid_19_ny_sbu          1384         7361       17950
# 8          prostate_mri_us_biopsy          1151         2799       10373
# 9                       tcga_brca          1098         1263       10463
# 10                      lidc_idri          1010         1308       15116
# 11  acrin_contralateral_breast_mr           984         1103       10184
# 12                           gtex           971          971       25503
# 13         duke_breast_cancer_mri           922          922        6058
# 14                         pdxnet           919          919         919
# 15                ct_colonography           825          836        3451
# 16                          ispy2           719         2688       32411
# 17    advanced_mri_breast_lesions           632          632        6811
# 18                      upenn_gbm           630         3301        6064
# 19                       tcga_gbm           607          607        4286
#
#                            modalities  total_size_MB
# 0                     SEG, SR, CT, SM     26354750.2
# 1                                  MG       163513.0
# 2                                  MG      1637812.4
# 3                                  SM      4657163.1
# 4                                  MG      1027194.8
# 5   SEG, CT, MR, PT, NM, RTSTRUCT, XA       797262.8
# 6                                  MG        22861.9
# 7      OT, MR, CR, PT, NM, SR, DX, CT       511477.8
# 8                    MR, M3D, SEG, US        81631.1
# 9            SR, SM, ANN, SEG, MG, MR      3081928.9
# 10                SR, CR, DX, CT, SEG       136547.9
# 11                             MR, CR       199593.3
# 12                                 SM      8554686.4
# 13                            MR, SEG       377371.2
# 14                                 SM       125612.6
# 15                                 CT       496672.2
# 16                            MR, SEG      1746234.3
# 17                            MR, SEG       645619.2
# 18                            SEG, MR       141312.2
# 19                   SEG, OT, SM, ANN      1057632.5

# %% [markdown]
# ## Collections Index — Cancer Types and Tumor Locations

# %%
client.fetch_index("collections_index")

# Note: idc-index 0.12 renamed the collections_index columns from CamelCase to
# snake_case (CancerTypes -> cancer_types, etc.) and added program_id, status,
# updated and description.
collections_info = client.sql_query("""
    SELECT collection_id, program_id, cancer_types, tumor_locations,
           species, subjects, supporting_data
    FROM collections_index
    ORDER BY subjects DESC
""")
collections_info.head(20)
# Out:
# 2026-08-31 09:55:37,082 - Index collections_index already installed, loading from /Users/af61/github/idc-cda/.venv/lib/python3.11/site-packages/idc_index_data/collections_index.parquet
#                     collection_id  program_id  \
# 0                            nlst  nci_trials
# 1                       cbis_ddsm   community
# 2     breast_cancer_screening_dbt   community
# 3                        ccdi_mci        ccdi
# 4                          victre         fda
# 5                          eay131        nctn
# 6                            cmmd   community
# 7                 covid_19_ny_sbu    covid_19
# 8          prostate_mri_us_biopsy   community
# 9                       tcga_brca        tcga
# 10                      lidc_idri   community
# 11  acrin_contralateral_breast_mr  nci_trials
# 12                           gtex         nih
# 13         duke_breast_cancer_mri   community
# 14                         pdxnet         nih
# 15                ct_colonography  nci_trials
# 16                          ispy2  nci_trials
# 17    advanced_mri_breast_lesions   community
# 18                      upenn_gbm   community
# 19                       tcga_gbm        tcga
#
#                                          cancer_types  \
# 0                             Lung Cancer, Non-Cancer
# 1                           Breast Cancer, Non-Cancer
# 2                           Breast Cancer, Non-Cancer
# 3                                             Various
# 4                                       Breast Cancer
# 5   Adenocarcinoma, Adrenocortical Carcinoma, Anal...
# 6                                       Breast Cancer
# 7                               COVID-19 (non-cancer)
# 8                                     Prostate Cancer
# 9                                       Breast Cancer
# 10        Lung Cancer, Non-Cancer, Metastatic disease
# 11                                      Breast Cancer
# 12                                       Non-diseased
# 13                                      Breast Cancer
# 14  Acinar Cell Carcinoma, Adrenal Cortical Carcin...
# 15                                       Colon Cancer
# 16                                      Breast Cancer
# 17                                      Breast Cancer
# 18                                       Glioblastoma
# 19                            Glioblastoma Multiforme
#
#                                       tumor_locations       species  subjects  \
# 0                                               Chest         Human     26410
# 1                                              Breast         Human      6671
# 2                                              Breast         Human      5060
# 3                                             Various         Human      4407
# 4                                              Breast         Human      2994
# 5                                             Various         Human      2813
# 6                                              Breast         Human      1775
# 7                                                Lung         Human      1384
# 8                                            Prostate         Human      1151
# 9                                              Breast         Human      1098
# 10                                              Chest         Human      1010
# 11                                             Breast         Human       984
# 12                                            Various         Human       971
# 13                                             Breast         Human       922
# 14  adrenal gland, bladder organ, bone element, br...  Human, Mouse       919
# 15                                              Colon         Human       825
# 16                                             Breast         Human       719
# 17                                             Breast         Human       632
# 18                                              Brain         Human       630
# 19                                              Brain         Human       607
#
#                                       supporting_data
# 0                                            Clinical
# 1                                      Image Analyses
# 2                      Clinical, Software/Source Code
# 3
# 4                                Software/Source Code
# 5                                            Clinical
# 6                                            Clinical
# 7                            Clinical, Image Analyses
# 8                                      Image Analyses
# 9   Clinical, Genomics, Image Analyses, Histopatho...
# 10     Clinical, Image Analyses, Software/Source Code
# 11                                           Clinical
# 12                                 Clinical, Genomics
# 13                 Clinical, Genomics, Image Analyses
# 14                 Clinical, Image Analyses, Genomics
# 15                                     Image Analyses
# 16                           Clinical, Image Analyses
# 17                                           Clinical
# 18                           Clinical, Image Analyses
# 19  Clinical, Genomics, Image Analyses, Histopatho...

# %% [markdown]
# ## Cross-Node Candidate Collections
#
# Collections from TCGA, CPTAC, and HTAN are most likely to have corresponding data in GDC (genomics) and PDC (proteomics).

# %%
# Tag collections by program
def tag_program(collection_id):
    cid = collection_id.lower()
    if cid.startswith('tcga_'):
        return 'TCGA'
    elif cid.startswith('cptac_'):
        return 'CPTAC'
    elif cid.startswith('htan_'):
        return 'HTAN'
    else:
        return 'Other'

collections_overview['program'] = collections_overview['collection_id'].apply(tag_program)

program_summary = collections_overview.groupby('program').agg(
    collections=('collection_id', 'count'),
    total_patients=('num_patients', 'sum'),
    total_series=('num_series', 'sum'),
    total_size_MB=('total_size_MB', 'sum')
).sort_values('total_patients', ascending=False)

program_summary
# Out:
#          collections  total_patients  total_series  total_size_MB
# program
# Other            125           72152        941814     69580258.1
# TCGA              32           11050         76292     25095387.9
# CPTAC             14            2171         14439      2901055.5
# HTAN               5              69           366      1690236.2

# %%
# TCGA collections detail
tcga = collections_overview[collections_overview['program'] == 'TCGA'].copy()
print(f"TCGA: {len(tcga)} collections, {tcga['num_patients'].sum()} total patients")
tcga
# Out:
# TCGA: 32 collections, 11050 total patients
#     collection_id  num_patients  num_studies  num_series  \
# 9       tcga_brca          1098         1263       10463
# 19       tcga_gbm           607          607        4286
# 20        tcga_ov           591          912        2537
# 21      tcga_luad           560          674        4868
# 22      tcga_ucec           560          786        4893
# 23      tcga_kirc           537          976        6038
# 24      tcga_hnsc           523          523        2163
# 25       tcga_lgg           516          516        1572
# 27      tcga_thca           507          514        1186
# 28      tcga_lusc           504          578        4170
# 29      tcga_prad           500          520        3336
# 31      tcga_skcm           470          470        3160
# 32      tcga_coad           464          492        3766
# 33      tcga_stad           443          489        3449
# 35      tcga_blca           412          604        3876
# 41      tcga_lihc           377          614        3457
# 46      tcga_cesc           307          364        2370
# 47      tcga_kirp           291          338        1168
# 49      tcga_sarc           261          267        1431
# 68      tcga_esca           185          202         834
# 69      tcga_paad           185          185        1414
# 70      tcga_pcpg           179          179         385
# 75      tcga_read           171          175        1381
# 77      tcga_tgct           150          150         721
# 80      tcga_thym           124          124         560
# 85      tcga_kich           113          128         450
# 92       tcga_acc            92           92         969
# 98      tcga_meso            87           87         525
# 102      tcga_uvm            80           80         497
# 114      tcga_ucs            57           57         154
# 119     tcga_chol            51           51         110
# 122     tcga_dlbc            48           48         103
#
#                            modalities  total_size_MB program
# 9            SR, SM, ANN, SEG, MG, MR      3081928.9    TCGA
# 19                   SEG, OT, SM, ANN      1057632.5    TCGA
# 20                OT, MR, SM, CT, SEG       516249.5    TCGA
# 21           SEG, ANN, PT, NM, SM, CT      1284054.2    TCGA
# 22       SEG, SM, CT, MR, PT, CR, ANN      2065212.8    TCGA
# 23                MR, SEG, CR, SM, CT       923543.1    TCGA
# 24                            SM, SEG       574053.0    TCGA
# 25                                 SM      1194589.9    TCGA
# 27                         SM, CT, PT       766136.8    TCGA
# 28           ANN, PT, NM, SM, CT, SEG      1101494.9    TCGA
# 29           SEG, SM, CT, MR, PT, ANN      1059659.9    TCGA
# 31                       SEG, ANN, SM      1345955.3    TCGA
# 32               SM, CT, SEG, ANN, OT       931178.4    TCGA
# 33                   SEG, ANN, SM, CT      1135001.1    TCGA
# 35   ANN, SM, CT, DX, CR, PT, MR, SEG      1532252.2    TCGA
# 41                SEG, SM, CT, MR, PT       698200.7    TCGA
# 46                   MR, SEG, ANN, SM       621551.0    TCGA
# 47                MR, PT, SM, CT, SEG       432506.9    TCGA
# 49                    SM, CT, MR, SEG      1151228.4    TCGA
# 68                        SM, CT, SEG       253317.2    TCGA
# 69                       SM, ANN, SEG       555781.2    TCGA
# 70                                 SM       354667.5    TCGA
# 75               SEG, MR, SM, CT, ANN       290764.6    TCGA
# 77                            SEG, SM       472956.5    TCGA
# 80                            SM, SEG       327381.2    TCGA
# 85                    SM, CT, MR, SEG       318861.6    TCGA
# 92                            SM, SEG       431164.8    TCGA
# 98                            SM, SEG       114682.9    TCGA
# 102                      ANN, SEG, SM       179405.6    TCGA
# 114                                SM       168286.7    TCGA
# 119                                SM        99566.5    TCGA
# 122                                SM        56122.1    TCGA

# %%
# CPTAC collections detail
cptac = collections_overview[collections_overview['program'] == 'CPTAC'].copy()
print(f"CPTAC: {len(cptac)} collections, {cptac['num_patients'].sum()} total patients")
cptac
# Out:
# CPTAC: 14 collections, 2171 total patients
#     collection_id  num_patients  num_studies  num_series  \
# 50     cptac_ucec           254          396        3459
# 53     cptac_luad           244          319        1585
# 57    cptac_ccrcc           233          319        2321
# 60     cptac_lscc           212          255        1314
# 65     cptac_brca           198          198         653
# 67      cptac_pda           195          302        2226
# 71     cptac_coad           178          178         372
# 72      cptac_gbm           178          178         462
# 86    cptac_hnscc           112          112         390
# 91       cptac_cm            95          114         597
# 94      cptac_aml            91           98         169
# 97      cptac_sar            88          121         570
# 105      cptac_ov            73           73         222
# 145    cptac_stad            20           22          99
#
#                        modalities  total_size_MB program
# 50   SM, CT, PT, RTSTRUCT, US, MR       257358.9   CPTAC
# 53                 SM, CT, MR, PT       521547.7   CPTAC
# 57      RTSTRUCT, SM, CT, MR, SEG       277024.9   CPTAC
# 60                     SM, CT, PT       509698.9   CPTAC
# 65                             SM       123127.3   CPTAC
# 67   RTSTRUCT, US, SM, CT, PT, MR       170156.3   CPTAC
# 71                             SM        70234.4   CPTAC
# 72                             SM       100948.5   CPTAC
# 86                             SM       111422.2   CPTAC
# 91                 CT, SM, PT, MR       156256.6   CPTAC
# 94                     US, SM, CT       425271.7   CPTAC
# 97                 SM, CT, PT, MR        98590.6   CPTAC
# 105                            SM        58425.7   CPTAC
# 145                        CT, US        20991.8   CPTAC

# %%
# HTAN collections detail
htan = collections_overview[collections_overview['program'] == 'HTAN'].copy()
print(f"HTAN: {len(htan)} collections, {htan['num_patients'].sum()} total patients")
htan
# Out:
# HTAN: 5 collections, 69 total patients
#         collection_id  num_patients  num_studies  num_series modalities  \
# 135   htan_vanderbilt            30           30          30         SM
# 142        htan_wustl            21           21         228     SM, PR
# 153          htan_hms            16           16          31     SM, PR
# 171  htan_tnp_sardana             1            1           3     SM, PR
# 172         htan_ohsu             1            1          74     SM, PR
#
#      total_size_MB program
# 135        69497.9    HTAN
# 142        12255.1    HTAN
# 153      1232544.7    HTAN
# 171        44216.5    HTAN
# 172       331722.0    HTAN

# %% [markdown]
# ## Extract PatientIDs for Cross-Node Candidate Collections
#
# Get distinct PatientIDs from TCGA and CPTAC collections for later cross-referencing with CDA.

# %%
# All TCGA patient IDs
tcga_patients = client.sql_query("""
    SELECT DISTINCT collection_id, PatientID
    FROM index
    WHERE collection_id LIKE 'tcga_%'
    ORDER BY collection_id, PatientID
""")
print(f"TCGA patients in IDC: {len(tcga_patients)}")
tcga_patients.head(10)
# Out:
# TCGA patients in IDC: 11050
#   collection_id     PatientID
# 0      tcga_acc  TCGA-OR-A5J1
# 1      tcga_acc  TCGA-OR-A5J2
# 2      tcga_acc  TCGA-OR-A5J3
# 3      tcga_acc  TCGA-OR-A5J4
# 4      tcga_acc  TCGA-OR-A5J5
# 5      tcga_acc  TCGA-OR-A5J6
# 6      tcga_acc  TCGA-OR-A5J7
# 7      tcga_acc  TCGA-OR-A5J8
# 8      tcga_acc  TCGA-OR-A5J9
# 9      tcga_acc  TCGA-OR-A5JA

# %%
# All CPTAC patient IDs
cptac_patients = client.sql_query("""
    SELECT DISTINCT collection_id, PatientID
    FROM index
    WHERE collection_id LIKE 'cptac_%'
    ORDER BY collection_id, PatientID
""")
print(f"CPTAC patients in IDC: {len(cptac_patients)}")
cptac_patients.head(10)
# Out:
# CPTAC patients in IDC: 2171
#   collection_id  PatientID
# 0     cptac_aml  C3L-00452
# 1     cptac_aml  C3L-00453
# 2     cptac_aml  C3L-00455
# 3     cptac_aml  C3L-00457
# 4     cptac_aml  C3L-00458
# 5     cptac_aml  C3L-00459
# 6     cptac_aml  C3L-00460
# 7     cptac_aml  C3L-00461
# 8     cptac_aml  C3L-00465
# 9     cptac_aml  C3L-00540

# %%
# All HTAN patient IDs
htan_patients = client.sql_query("""
    SELECT DISTINCT collection_id, PatientID
    FROM index
    WHERE collection_id LIKE 'htan_%'
    ORDER BY collection_id, PatientID
""")
print(f"HTAN patients in IDC: {len(htan_patients)}")
htan_patients.head(10)
# Out:
# HTAN patients in IDC: 69
#   collection_id PatientID
# 0      htan_hms  HTA7_920
# 1      htan_hms  HTA7_922
# 2      htan_hms  HTA7_925
# 3      htan_hms  HTA7_926
# 4      htan_hms  HTA7_927
# 5      htan_hms  HTA7_931
# 6      htan_hms  HTA7_932
# 7      htan_hms  HTA7_934
# 8      htan_hms  HTA7_940
# 9      htan_hms  HTA7_947

# %% [markdown]
# ## Modality Distribution Across Programs

# %%
modality_by_program = client.sql_query("""
    SELECT
        CASE
            WHEN collection_id LIKE 'tcga_%' THEN 'TCGA'
            WHEN collection_id LIKE 'cptac_%' THEN 'CPTAC'
            WHEN collection_id LIKE 'htan_%' THEN 'HTAN'
            ELSE 'Other'
        END as program,
        Modality,
        COUNT(DISTINCT PatientID) as patients,
        COUNT(DISTINCT SeriesInstanceUID) as series
    FROM index
    GROUP BY program, Modality
    ORDER BY program, patients DESC
""")
modality_by_program
# Out:
#    program  Modality  patients  series
# 0    CPTAC        SM      2107    7377
# 1    CPTAC        CT       365    3241
# 2    CPTAC  RTSTRUCT       235    1789
# 3    CPTAC        MR        81    1907
# 4    CPTAC        PT        29      80
# 5    CPTAC       SEG        14      37
# 6    CPTAC        US         8       8
# 7     HTAN        SM        69     259
# 8     HTAN        PR        26     107
# 9    Other        CT     37268  257557
# 10   Other       SEG     34924  162565
# 11   Other        SR     28926  270523
# 12   Other        MG     17021   48106
# 13   Other        SM      9462   38588
# 14   Other        MR      7730  118156
# 15   Other  RTSTRUCT      4013   17569
# 16   Other        CR      1696   12394
# 17   Other        PT      1589    4649
# 18   Other        US      1404    2233
# 19   Other       M3D       842    2328
# 20   Other        DX       665    3694
# 21   Other    RTDOSE       282     524
# 22   Other       ANN       245    1027
# 23   Other    RTPLAN       242     484
# 24   Other        PR        41    1086
# 25   Other        NM        24      89
# 26   Other       REG        23      97
# 27   Other       RWV        20      20
# 28   Other        XA        16      35
# 29   Other        KO        10      40
# 30   Other    FUSION         6      18
# 31   Other        OT         4      16
# 32   Other        XC         2       4
# 33   Other        RF         2      12
# 34    TCGA        SM     11007   30075
# 35    TCGA       SEG      7968   27556
# 36    TCGA       ANN      5185    6075
# 37    TCGA        CT       870    6370
# 38    TCGA        MR       355    5109
# 39    TCGA        OT       338     693
# 40    TCGA        SR       139     164
# 41    TCGA        PT        65     180
# 42    TCGA        CR         9      22
# 43    TCGA        DX         7      18
# 44    TCGA        MG         5      19
# 45    TCGA        NM         4      11

# %% [markdown]
# ## Save Results for Cross-Node Analysis

# %%
data_dir = Path('data')
data_dir.mkdir(exist_ok=True)

collections_overview.to_csv(data_dir / 'collections_overview.csv', index=False)
tcga_patients.to_csv(data_dir / 'tcga_patients.csv', index=False)
cptac_patients.to_csv(data_dir / 'cptac_patients.csv', index=False)
htan_patients.to_csv(data_dir / 'htan_patients.csv', index=False)

print("Saved:")
print(f"  collections_overview.csv: {len(collections_overview)} rows")
print(f"  tcga_patients.csv: {len(tcga_patients)} rows")
print(f"  cptac_patients.csv: {len(cptac_patients)} rows")
print(f"  htan_patients.csv: {len(htan_patients)} rows")
# Out:
# Saved:
#   collections_overview.csv: 176 rows
#   tcga_patients.csv: 11050 rows
#   cptac_patients.csv: 2171 rows
#   htan_patients.csv: 69 rows
